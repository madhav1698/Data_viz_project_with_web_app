# %%
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
from pytz import utc
data=pd.read_csv("reviews.csv",parse_dates=["Timestamp"]) #parses timetsamp column as datetime

# %%
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment
# 0 2021-04-02 06:25:52+00:00     4.0     NaN
# 1 2021-04-02 05:12:34+00:00     4.0     NaN
# 2 2021-04-02 05:11:03+00:00     4.0     NaN
# 3 2021-04-02 03:33:24+00:00     5.0     NaN
# 4 2021-04-02 03:31:49+00:00     4.5     NaN

# %%
data["Day"]=data["Timestamp"].dt.date
day_average= data.groupby(["Day"]).mean()
day_average
# Out:
#               Rating
# Day
# 2018-01-01  4.532609
# 2018-01-02  4.122807
# 2018-01-03  4.360465
# 2018-01-04  4.531250
# 2018-01-05  4.423077
# ...              ...
# 2021-03-29  4.240000
# 2021-03-30  4.428571
# 2021-03-31  4.453125
# 2021-04-01  4.592593
# 2021-04-02  4.357143
#
# [1188 rows x 1 columns]

# %%
plt.figure(figsize=(25,3))
plt.plot(day_average.index,day_average["Rating"])

# %%
###Rating avg by week

# %%
data["Week"]=data["Timestamp"].dt.strftime("%Y-%W") #string from time
week_avg=data.groupby(["Week"]).mean()
plt.figure(figsize=(25,3))
plt.plot(week_avg.index,week_avg["Rating"])

# %%
##avg rating by month
data["Month"]=data["Timestamp"].dt.strftime("%Y-%m") #string from time
month_avg=data.groupby(["Month"]).mean()
plt.figure(figsize=(25,3))
plt.plot(month_avg.index,month_avg["Rating"])
month_avg
# Out:
#            Rating
# Month
# 2018-01  4.429645
# 2018-02  4.436248
# 2018-03  4.421671
# 2018-04  4.468211
# 2018-05  4.396420
# 2018-06  4.375379
# 2018-07  4.393184
# 2018-08  4.344753
# 2018-09  4.347247
# 2018-10  4.374429
# 2018-11  4.386817
# 2018-12  4.342105
# 2019-01  4.401920
# 2019-02  4.346964
# 2019-03  4.333145
# 2019-04  4.420049
# 2019-05  4.405569
# 2019-06  4.398559
# 2019-07  4.382353
# 2019-08  4.417059
# 2019-09  4.451135
# 2019-10  4.483871
# 2019-11  4.493260
# 2019-12  4.471046
# 2020-01  4.439615
# 2020-02  4.428642
# 2020-03  4.480690
# 2020-04  4.475220
# 2020-05  4.448082
# 2020-06  4.482812
# 2020-07  4.517508
# 2020-08  4.470987
# 2020-09  4.485862
# 2020-10  4.515201
# 2020-11  4.479306
# 2020-12  4.528358
# 2021-01  4.551325
# 2021-02  4.567901
# 2021-03  4.589207
# 2021-04  4.544118

# %%
### Average rting by month by course

# %%
data["Month"]= data["Timestamp"].dt.strftime("%y-%m")
month_avg_by_course=data.groupby(["Month","Course Name"]).mean().unstack() #for better structure
month_avg_by_course.plot(figsize=(25,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
###What day are people happiest?

# %%
data["Weekday"]=data["Timestamp"].dt.strftime("%A")
data["Daynumber"]=data["Timestamp"].dt.strftime("%w")

weekday_avg= data.groupby(["Weekday","Daynumber"]).mean()
weekday_avg=weekday_avg.sort_values("Daynumber")
weekday_avg.index.get_level_values(0) #extracts stuff at 0 index

plt.figure(figsize=(15,3))
plt.plot(weekday_avg.index.get_level_values(0),weekday_avg["Rating"])
